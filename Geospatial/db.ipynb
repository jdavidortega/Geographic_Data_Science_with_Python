# %% [markdown]
# # Una base de datos espacial para el curso
#
# Hasta ahora cada notebook abre sus archivos: un GeoJSON de barrios, un CSV de hurtos, un GeoPackage de la costa antártica.
# Funciona, pero cada archivo vive en una carpeta, con su propio formato y su propio sistema de referencia, y nadie más puede usarlo al mismo tiempo.
#
# En este notebook ponemos **todos esos datos en un mismo lugar**: una base de datos PostgreSQL con la extensión PostGIS, corriendo en un contenedor Docker en su computador.
# Desde ahí los consultamos con SQL, los leemos en Python y los abrimos en QGIS.
# Al final la pregunta es: ¿qué gano con una base de datos que no tenga ya con los archivos?

# %% [markdown]
# ## 0. Guía: crear el contenedor de la base de datos
#
# **Requisito**: [Docker Desktop](https://www.docker.com/products/docker-desktop/) instalado y abierto (la ballena en la barra de menú).
#
# Una sola orden en la terminal crea y arranca la base de datos. Cópiela completa (es una sola línea partida con `\`):
#
# ```bash
# docker run --name curso-postgis \
#   -e POSTGRES_USER=postgres \
#   -e POSTGRES_PASSWORD=1111 \
#   -e POSTGRES_DB=curso \
#   -p 5440:5432 \
#   -v curso_pgdata:/var/lib/postgresql/data \
#   -d postgis/postgis:15-3.4
# ```
#
# | Parte | Qué hace |
# |---|---|
# | `--name curso-postgis` | nombre del contenedor; con él se para y se arranca después |
# | `-e POSTGRES_USER=postgres` | usuario administrador de la base de datos |
# | `-e POSTGRES_PASSWORD=1111` | su contraseña (es local: solo su computador la ve) |
# | `-e POSTGRES_DB=curso` | crea una base de datos llamada `curso` al arrancar |
# | `-p 5440:5432` | publica el puerto: `puerto_en_su_computador:puerto_dentro_del_contenedor`. Dentro del contenedor PostgreSQL siempre escucha en 5432; afuera usamos **5440** para no chocar con otro PostgreSQL que ya esté usando el 5432 |
# | `-v curso_pgdata:/var/lib/postgresql/data` | volumen: los datos sobreviven aunque borre el contenedor |
# | `-d` | corre en segundo plano |
# | `postgis/postgis:15-3.4` | imagen oficial: PostgreSQL 15 con PostGIS 3.4 (la primera vez la descarga, ~400 MB) |
#
# Los **datos de conexión** que usaremos en todo el notebook y en QGIS son, por tanto:
#
# | host | puerto | base de datos | usuario | contraseña |
# |---|---|---|---|---|
# | `localhost` | `5440` | `curso` | `postgres` | `1111` |
#
# Órdenes útiles:
#
# ```bash
# docker ps                          # ¿está corriendo? debe aparecer curso-postgis
# docker logs curso-postgis          # la última línea debe decir "database system is ready to accept connections"
# docker stop curso-postgis          # apagarla (los datos quedan en el volumen)
# docker start curso-postgis         # volver a encenderla (no repita el docker run)
# docker exec -it curso-postgis psql -U postgres -d curso   # consola SQL dentro del contenedor (\q para salir)
# ```
#
# En un Mac con chip Apple, Docker puede avisar *requested image's platform (linux/amd64) does not match*: funciona igual, solo más lento; para evitarlo añada `--platform linux/arm64` antes del nombre de la imagen.
#
# Si el 5440 también estuviera ocupado, cambie solo el primer número (`-p 5441:5432`) y use ese mismo número como puerto en el notebook y en QGIS. Para saber qué contenedores ocupan qué puertos: `docker ps`.
#
# Del lado de Python hacen falta tres paquetes además de geopandas:
#
# ```bash
# pip install sqlalchemy psycopg2-binary geoalchemy2
# ```

# %% [markdown]
# ## 1. ¿Qué es una base de datos?
#
# Un archivo guarda datos. Una **base de datos** guarda datos *y* las reglas para usarlos: quién puede leerlos, qué tipo tiene cada columna, qué fila es cuál, y cómo encontrar rápido las que cumplen una condición.
# Un programa aparte, el **servidor** (aquí PostgreSQL), es el único que toca los archivos; todos los demás, Python, QGIS, una página web, le hablan en el mismo idioma, **SQL**, y él responde.
#
# Las piezas que vamos a usar:
#
# * **Tabla**: filas y columnas, como un `DataFrame`, pero cada columna tiene un tipo fijo (`integer`, `text`, `date`, …) que el servidor hace cumplir.
# * **Clave primaria**: la columna que identifica cada fila sin repetirse. QGIS la necesita para poder editar una capa.
# * **Consulta** (`SELECT … FROM … WHERE …`): describe *qué* quiere y el servidor decide *cómo* buscarlo.
# * **Índice**: una estructura auxiliar para que el `WHERE` no recorra toda la tabla.
# * **Vista**: una consulta guardada con nombre; se usa como si fuera una tabla.
#
# **PostGIS** añade un tipo de columna más: `geometry`. Una geometría lleva sus coordenadas, su tipo (punto, línea, polígono, y las versiones *multi*) y su **SRID**, el código EPSG del sistema de referencia en que están escritas esas coordenadas.
# Por eso una tabla de barrios puede estar en el origen nacional (9377), una de hurtos en coordenadas GPS (4326) y una de la costa antártica en proyección polar (3031), **las tres en la misma base de datos**, y el servidor sabe cómo pasar de una a otra.

# %% [markdown]
# ## 2. Conectarse
#
# La conexión se describe con una URL: `postgresql+psycopg2://usuario:contraseña@host:puerto/base_de_datos`.
# `create_engine` no abre nada todavía; la primera consulta lo hace.

# %%
import warnings; warnings.filterwarnings("ignore")
import pandas as pd, geopandas as gpd, numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, text

HOST, PUERTO, BD, USUARIO, CLAVE = "localhost", 5440, "curso", "postgres", "1111"
engine = create_engine(f"postgresql+psycopg2://{USUARIO}:{CLAVE}@{HOST}:{PUERTO}/{BD}")

try:
    with engine.connect() as con:
        print(con.execute(text("SELECT version()")).scalar())
except Exception as e:
    raise SystemExit("No hay conexión. ¿Está corriendo el contenedor? Revise `docker ps` y el puerto.\n" + str(e))
# Out:
# PostgreSQL 15.8 (Debian 15.8-1.pgdg110+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 10.2.1-6) 10.2.1 20210110, 64-bit

# %% [markdown]
# PostGIS es una *extensión*: viene en la imagen, pero cada base de datos la activa una vez.

# %%
with engine.begin() as con:                       # begin() = abre una transacción y la confirma al salir
    con.execute(text("CREATE EXTENSION IF NOT EXISTS postgis"))
    print(con.execute(text("SELECT postgis_version()")).scalar())
# Out:
# 3.4 USE_GEOS=1 USE_PROJ=1 USE_STATS=1

# %% [markdown]
# ## 3. Seis conjuntos de datos, tres tipos de geometría, cuatro sistemas de referencia
#
# Todos los archivos están en `data/`. Antes de meterlos a la base de datos, miremos qué es cada uno.
#
# | tabla | fuente | geometría | SRID | qué sistema es |
# |---|---|---|---|---|
# | `barrios` | GeoMedellín, barrios y veredas | polígonos | 9377 | MAGNA-SIRGAS / Origen Nacional (Colombia, metros) |
# | `cruces` | SIMM Medellín, cruces semafóricos | puntos | 9377 | ídem |
# | `camaras` | SIMM Medellín, cámaras de fotodetección | puntos | 6257 | MAGNA-SIRGAS / Medellín local (metros, origen en la ciudad) |
# | `hurtos` | MEData / SISC, hurto a residencia | puntos | 4326 | WGS 84, latitud–longitud del GPS (grados) |
# | `paises` | Natural Earth 1:110 m | polígonos | 4326 | ídem |
# | `costa_antartida` | SCAR Antarctic Digital Database v7.10 (simplificada a 1 km) | líneas | 3031 | Estereográfica polar sur (metros, origen en el polo) |

# %%
D = "./data/"
barrios = gpd.read_file(D + "barrios_y_veredas_mr.geojson")
cruces  = gpd.read_file(D + "cruces_semaforicos.geojson")
paises  = gpd.read_file(D + "ne_110m_admin_0_countries.geojson")[["NAME", "NAME_ES", "CONTINENT", "ISO_A3", "POP_EST", "GDP_MD", "geometry"]]
costa   = gpd.read_file(D + "costa_antartida_add_v7_simpl1km.gpkg")

# las cámaras vienen en CSV con tres pares de coordenadas para el mismo punto; usamos las locales (6257)
cam = pd.read_csv(D + "camaras_ars_simm_20250906.csv", thousands=",")
camaras = gpd.GeoDataFrame(cam[["OBJECTID", "DIRECCION", "LOCALIZACION", "LATITUD", "LONGITUD"]],
                           geometry=gpd.points_from_xy(cam.X_MAGNAMED, cam.Y_MAGNAMED), crs="EPSG:6257")

# los hurtos vienen en CSV con latitud/longitud; una fila por bien hurtado
h = pd.read_csv(D + "hurto_a_residencia.csv", low_memory=False)
h = h.dropna(subset=["latitud", "longitud"]).query("latitud != 0 and longitud != 0")
h["fecha_hecho"] = pd.to_datetime(h.fecha_hecho, utc=True).dt.tz_convert("America/Bogota").dt.tz_localize(None)
hurtos = gpd.GeoDataFrame(h[["fecha_hecho", "modalidad", "bien", "categoria_bien", "nombre_barrio", "codigo_barrio", "codigo_comuna", "sexo", "edad"]],
                          geometry=gpd.points_from_xy(h.longitud, h.latitud), crs="EPSG:4326")

# barrios y países mezclan Polygon y MultiPolygon; una tabla con un solo tipo es más cómoda para QGIS
from shapely.geometry import MultiPolygon
a_multi = lambda g: MultiPolygon([g]) if g.geom_type == "Polygon" else g
barrios["geometry"] = barrios.geometry.apply(a_multi)
paises["geometry"]  = paises.geometry.apply(a_multi)

capas = {"barrios": barrios, "cruces": cruces, "camaras": camaras, "hurtos": hurtos, "paises": paises, "costa_antartida": costa}
pd.DataFrame({n: dict(filas=len(g), geometria=g.geom_type.mode()[0], srid=g.crs.to_epsg(), unidades=g.crs.axis_info[0].unit_name)
              for n, g in capas.items()}).T
# Out:
#                  filas     geometria  srid unidades
# barrios            332  MultiPolygon  9377    metre
# cruces             724         Point  9377    metre
# camaras             22         Point  6257    metre
# hurtos           38343         Point  4326   degree
# paises             177  MultiPolygon  4326   degree
# costa_antartida   2149    LineString  3031    metre

# %% [markdown]
# Un mismo lugar, tres tuplas de números. La primera cámara del SIMM está descrita en el CSV en coordenadas locales y en latitud–longitud;
# si además la llevamos al origen nacional, son tres formas de escribir el mismo punto. Ninguna es «la verdadera»: cada una es útil en su contexto.

# %%
p = camaras.iloc[[0]]
pd.DataFrame({
    "EPSG:6257 local (m)":     [p.geometry.x.iloc[0], p.geometry.y.iloc[0]],
    "EPSG:9377 nacional (m)":  [p.to_crs(9377).geometry.x.iloc[0], p.to_crs(9377).geometry.y.iloc[0]],
    "EPSG:4326 GPS (grados)":  [p.to_crs(4326).geometry.x.iloc[0], p.to_crs(4326).geometry.y.iloc[0]],
    "CSV (LONGITUD, LATITUD)": [p.LONGITUD.iloc[0], p.LATITUD.iloc[0]],
}, index=["x / lon", "y / lat"]).round(6)
# Out:
#          EPSG:6257 local (m)  EPSG:9377 nacional (m)  EPSG:4326 GPS (grados)  \
# x / lon         8.344256e+05            4.715320e+06              -75.573496
# y / lat         1.178048e+06            2.244241e+06                6.204176
#
#          CSV (LONGITUD, LATITUD)
# x / lon               -75.573496
# y / lat                 6.204176

# %% [markdown]
# ### ¿Conoce el servidor estos sistemas?
#
# PostGIS trae una tabla, `spatial_ref_sys`, con la definición de unos 8 500 sistemas de referencia; es lo que usa para transformar.
# Pero es una copia fija del registro EPSG y los dos sistemas colombianos recientes, el origen nacional (9377, de 2020) y el local de Medellín (6257), no están.
# `pyproj` sí los conoce: le pedimos la definición y la registramos en la base de datos. Sin este paso, `ST_Transform` sobre esas tablas falla con *Cannot find SRID in spatial_ref_sys*.

# %%
from pyproj import CRS
codigos = sorted({g.crs.to_epsg() for g in capas.values()} | {6933})   # 6933: igual área, la usaremos más adelante
with engine.begin() as con:
    conocidos = {r[0] for r in con.execute(text("SELECT srid FROM spatial_ref_sys WHERE srid = ANY(:c)"), {"c": codigos})}
    for srid in codigos:
        if srid in conocidos:
            continue
        crs = CRS.from_epsg(srid)
        try:
            wkt = crs.to_wkt(version="WKT1_GDAL")      # el formato clásico de srtext
        except Exception:
            wkt = crs.to_wkt(version="WKT2_2019")      # 6257 (proyección "Colombia Urban") solo existe en WKT2
        con.execute(text("INSERT INTO spatial_ref_sys (srid, auth_name, auth_srid, srtext, proj4text) VALUES (:s, 'EPSG', :s, :wkt, :p4)"),
                    {"s": srid, "wkt": wkt, "p4": crs.to_proj4()})
        print(f"registrado EPSG:{srid}  {crs.name}")
pd.read_sql('SELECT srid, split_part(srtext, \'"\', 2) AS nombre, left(proj4text, 60) AS proj4 FROM spatial_ref_sys WHERE srid = ANY(%(c)s) ORDER BY srid',
            engine, params={"c": codigos})
# Out:
#    srid                                  nombre  \
# 0  3031  WGS 84 / Antarctic Polar Stereographic
# 1  4326                                  WGS 84
# 2  6257      MAGNA-SIRGAS / Medellin urban grid
# 3  6933     WGS 84 / NSIDC EASE-Grid 2.0 Global
# 4  9377     MAGNA-SIRGAS 2018 / Origen-Nacional
#
#                                                proj4
# 0  +proj=stere +lat_0=-90 +lat_ts=-71 +lon_0=0 +k...
# 1               +proj=longlat +datum=WGS84 +no_defs
# 2  +proj=col_urban +lat_0=6.22920888888889 +lon_0...
# 3  +proj=cea +lon_0=0 +lat_ts=30 +x_0=0 +y_0=0 +d...
# 4  +proj=tmerc +lat_0=4 +lon_0=-73 +k=0.9992 +x_0...

# %% [markdown]
# Tener el mismo punto escrito dos veces también sirve de control de calidad. Si llevamos las coordenadas locales a GPS y las comparamos con las columnas `LATITUD`/`LONGITUD` del mismo CSV, deberían coincidir a menos de un metro.

# %%
desde_latlon = gpd.GeoSeries(gpd.points_from_xy(camaras.LONGITUD, camaras.LATITUD), crs=4326).to_crs(6257)
camaras["dif_m"] = camaras.geometry.distance(desde_latlon).round(1)
camaras.sort_values("dif_m", ascending=False)[["OBJECTID", "DIRECCION", "LATITUD", "LONGITUD", "dif_m"]].head(3)
# Out:
#     OBJECTID         DIRECCION   LATITUD   LONGITUD      dif_m
# 17       326       Cr 65 Cl 30  6.231808 -75.582778  1063000.0
# 0          8  Cr 43C Cl 1A Sur  6.204176 -75.573496        0.0
# 1          6       Cr 75B Cl 5  6.216199 -75.597714        0.0

# %% [markdown]
# Una cámara está a más de mil kilómetros de sí misma: en el CSV a su `Y_MAGNAMED` le falta un dígito (`118,104` por `1,181,104`). Es un error de la fuente, no del sistema de referencia.
# Antes de guardar en la base de datos la corregimos a partir de la latitud–longitud, y dejamos constancia en una columna: quien abra la tabla dentro de un año sabrá qué se tocó.

# %%
malas = camaras.dif_m > 1
camaras.loc[malas, "geometry"] = desde_latlon[malas]
camaras["nota"] = np.where(malas, "coordenada local corregida desde LATITUD/LONGITUD", None)
camaras = camaras.drop(columns="dif_m")
print(malas.sum(), "corregida(s)")
# Out:
# 1 corregida(s)

# %% [markdown]
# ## 4. Meterlos a la base de datos
#
# `GeoDataFrame.to_postgis` crea la tabla, una columna por atributo con su tipo, y la columna `geometry` con el SRID que trae el `crs`.
# Con `if_exists="replace"` se puede volver a correr la celda sin error (salvo por un detalle que el propio servidor impone: si ya existe una vista que depende de la tabla, hay que quitarla antes; la base de datos no permite dejar objetos colgando). Después de crearlas, a cada tabla le añadimos dos cosas que `to_postgis` no pone y que QGIS agradece:
# una **clave primaria** entera (`id`) y un **índice espacial** (GIST) sobre la geometría.

# %%
with engine.begin() as con:
    con.execute(text("DROP VIEW IF EXISTS v_hurtos_barrio"))   # la vista de la sección 5 depende de barrios y hurtos:
                                                              # el servidor no deja reemplazar una tabla de la que algo depende
for nombre, g in capas.items():
    g.to_postgis(nombre, engine, if_exists="replace", index=False, chunksize=5000)
    with engine.begin() as con:
        con.execute(text(f"ALTER TABLE {nombre} ADD COLUMN id SERIAL PRIMARY KEY"))
        con.execute(text(f"CREATE INDEX {nombre}_geom_idx ON {nombre} USING GIST (geometry)"))
    print(f"{nombre:16s} {len(g):6d} filas")
# Out:
# barrios             332 filas
# cruces              724 filas
# camaras              22 filas
# hurtos            38343 filas
# paises              177 filas
# costa_antartida    2149 filas

# %% [markdown]
# La base de datos ahora *sabe* qué hay en cada tabla. La vista `geometry_columns` es el catálogo que QGIS lee cuando le pedimos «añadir capa PostGIS»:
# tipo de geometría, dimensión y SRID de cada columna espacial.

# %%
pd.read_sql("SELECT f_table_name AS tabla, f_geometry_column AS columna, type AS tipo, srid FROM geometry_columns ORDER BY srid, tabla", engine)
# Out:
#               tabla   columna             tipo  srid
# 0   costa_antartida  geometry       LINESTRING  3031
# 1          addrfeat  the_geom       LINESTRING  4269
# 2                bg  the_geom     MULTIPOLYGON  4269
# 3            county  the_geom     MULTIPOLYGON  4269
# 4            cousub  the_geom     MULTIPOLYGON  4269
# 5             edges  the_geom  MULTILINESTRING  4269
# 6             faces  the_geom     MULTIPOLYGON  4269
# 7             place  the_geom     MULTIPOLYGON  4269
# 8             state  the_geom     MULTIPOLYGON  4269
# 9          tabblock  the_geom     MULTIPOLYGON  4269
# 10       tabblock20  the_geom     MULTIPOLYGON  4269
# 11            tract  the_geom     MULTIPOLYGON  4269
# 12            zcta5  the_geom     MULTIPOLYGON  4269
# 13           hurtos  geometry            POINT  4326
# 14           paises  geometry     MULTIPOLYGON  4326
# 15          camaras  geometry            POINT  6257
# 16          barrios  geometry     MULTIPOLYGON  9377
# ...

# %%
# los tipos de cada columna de una tabla, como los ve el servidor
pd.read_sql("""
    SELECT column_name, data_type, udt_name
    FROM information_schema.columns
    WHERE table_name = 'hurtos' ORDER BY ordinal_position""", engine)
# Out:
#        column_name                    data_type   udt_name
# 0      fecha_hecho  timestamp without time zone  timestamp
# 1        modalidad                         text       text
# 2             bien                         text       text
# 3   categoria_bien                         text       text
# 4    nombre_barrio                         text       text
# 5    codigo_barrio                         text       text
# 6    codigo_comuna                         text       text
# 7             sexo                         text       text
# 8             edad                       bigint       int8
# 9         geometry                 USER-DEFINED   geometry
# 10              id                      integer       int4

# %% [markdown]
# ## 5. Preguntarle a la base de datos
#
# Una consulta SQL se lee casi como una frase: *selecciona estas columnas, de esta tabla, donde se cumpla esto, ordenadas así*.
# `pd.read_sql` devuelve el resultado como `DataFrame`; el trabajo lo hace el servidor, no Python.

# %%
pd.read_sql("""
    SELECT codigo, nombre, ROUND((ST_Area(geometry) / 1e6)::numeric, 2) AS area_km2
    FROM barrios
    WHERE subtipo_barriovereda = 1            -- solo barrios urbanos
      AND limitecomunacorregimientoid = '14'  -- comuna 14, El Poblado
    ORDER BY area_km2 DESC
    LIMIT 8""", engine)
# Out:
#   codigo             nombre  area_km2
# 0   1411    Los Balsos No.1      1.40
# 1   1412          San Lucas      1.23
# 2   1409          El Tesoro      1.17
# 3   1410       Los Naranjos      0.97
# 4   1403      Villa Carlota      0.94
# 5   1408  Altos del Poblado      0.91
# 6   1417         La Florida      0.77
# 7   1421       Patio Bonito      0.73

# %% [markdown]
# `ST_Area(geometry)` devolvió metros cuadrados sin que le dijéramos nada: la tabla está en EPSG:9377, que es métrico.
# Con los países, que están en grados, la misma función daría «grados cuadrados», un número sin sentido. Dos salidas: transformar a una proyección de igual área, o usar el tipo `geography`, que calcula sobre el elipsoide.

# %%
pd.read_sql("""
    SELECT "NAME_ES" AS pais,
           ROUND(ST_Area(geometry)::numeric, 1)                       AS area_grados2,
           ROUND((ST_Area(geometry::geography) / 1e6)::numeric)       AS area_km2_elipsoide,
           ROUND((ST_Area(ST_Transform(geometry, 6933)) / 1e6)::numeric) AS area_km2_igual_area
    FROM paises
    WHERE "CONTINENT" = 'South America'
    ORDER BY area_km2_elipsoide DESC
    LIMIT 6""", engine)
# Out:
#         pais  area_grados2  area_km2_elipsoide  area_km2_igual_area
# 0     Brasil         710.2           8508557.0            8508161.0
# 1  Argentina         278.9           2784469.0            2784385.0
# 2       Perú         108.0           1309700.0            1309483.0
# 3   Colombia          93.9           1151883.0            1151855.0
# 4    Bolivia          92.1           1085270.0            1085182.0
# 5  Venezuela          74.4            908499.0             908470.0

# %% [markdown]
# ### Mezclar sistemas de referencia
#
# Las cámaras están en 6257 y los cruces en 9377. Si preguntamos qué cámaras están a menos de 100 m de un cruce **sin transformar**, pasan dos cosas distintas según la función.
# `ST_DWithin` usa primero el índice: compara cajas envolventes, y como los números de un sistema y del otro nunca se cruzan, devuelve **cero en silencio**: un resultado falso sin error.
# `ST_Distance` sí se detiene y explica. La lección es la misma que con los archivos: el SRID hay que mirarlo antes, no confiar en que algo avise.

# %%
print("ST_DWithin sin transformar:", pd.read_sql("SELECT count(*) FROM camaras c JOIN cruces r ON ST_DWithin(c.geometry, r.geometry, 100)", engine).iloc[0, 0])
try:
    pd.read_sql("SELECT count(*) FROM camaras c JOIN cruces r ON ST_Distance(c.geometry, r.geometry) < 100", engine)
except Exception as e:
    import re
    print("ST_Distance sin transformar:", re.search(r"ST_Distance: [^\n]*", str(e)).group())
# Out:
# ST_DWithin sin transformar: 0
# ST_Distance sin transformar: ST_Distance: Operation on mixed SRID geometries (Point, 6257) != (Point, 9377)

# %% [markdown]
# `ST_Transform` reproyecta al vuelo usando la tabla `spatial_ref_sys` (los mismos códigos EPSG de `pyproj`). Aquí llevamos las cámaras al 9377 de los cruces:

# %%
pd.read_sql("""
    SELECT c.id AS camara, c."DIRECCION" AS direccion_camara, r.id_cruce,
           ROUND(ST_Distance(ST_Transform(c.geometry, 9377), r.geometry)::numeric, 1) AS dist_m
    FROM camaras c
    JOIN cruces r ON ST_DWithin(ST_Transform(c.geometry, 9377), r.geometry, 100)
    ORDER BY dist_m
    LIMIT 10""", engine)
# Out:
#    camara direccion_camara  id_cruce  dist_m
# 0      22      Cr 46 Cl 52       178     1.1
# 1       4      Cr 65 Cl 80       421     1.8
# 2      14      Cr 70 Cl 44       467     2.9
# 3      13     Av 80 Cl 30A       533     4.7
# 4      21     Cr 43A Cl 31       102     5.1
# 5      17      Cr 65 Cl 41       399     5.2
# 6      16      Cr 65 Cl 44       411     7.4
# 7      15      Cr 65 Cl 50       416     8.3
# 8       6      Cr 46 Cl 41       172     9.4
# 9       5      Cr 46 Cl 57       182     9.5

# %%
pd.read_sql("""
    SELECT count(DISTINCT c.id) AS camaras_con_cruce_a_100m, (SELECT count(*) FROM camaras) AS camaras_total
    FROM camaras c JOIN cruces r ON ST_DWithin(ST_Transform(c.geometry, 9377), r.geometry, 100)""", engine)
# Out:
#    camaras_con_cruce_a_100m  camaras_total
# 0                        22             22

# %% [markdown]
# ### La unión espacial, ahora en el servidor
#
# En el notebook de coropletas contamos hurtos por barrio con `sjoin`. En SQL es un `JOIN` con la condición `ST_Contains`, y `GROUP BY` hace el conteo.
# Los hurtos están en 4326 y los barrios en 9377: otra vez `ST_Transform`. El índice GIST es lo que hace que 38 mil puntos contra 332 polígonos tarde segundos y no minutos.

# %%
# %%time
hurtos_barrio = pd.read_sql("""
    SELECT b.codigo, b.nombre,
           count(h.id)                                             AS bienes_hurtados,
           count(DISTINCT (h.fecha_hecho, h.geometry))             AS hechos,
           ROUND((ST_Area(b.geometry) / 1e6)::numeric, 3)          AS area_km2
    FROM barrios b
    LEFT JOIN hurtos h ON ST_Contains(b.geometry, ST_Transform(h.geometry, 9377))
    WHERE b.subtipo_barriovereda = 1
    GROUP BY b.id, b.codigo, b.nombre, b.geometry
    ORDER BY hechos DESC""", engine)
hurtos_barrio.head(8)
# Out:
# CPU times: user 4.24 ms, sys: 1.85 ms, total: 6.09 ms
# Wall time: 6.1 s
#   codigo              nombre  bienes_hurtados  hechos  area_km2
# 0   1108            Laureles              700     265     0.707
# 1   1105  Los Conquistadores              653     221     0.683
# 2   1016              Boston              471     208     0.536
# 3   1603               Belén              491     201     0.535
# 4   1114         Los Colores              525     198     0.555
# 5   1602             Rosales              541     192     0.605
# 6   1605        San Bernardo              490     185     0.568
# 7   1001               Prado              378     175     0.624

# %% [markdown]
# Si esa consulta es útil para varias personas, se guarda como **vista**: una tabla virtual que se recalcula cada vez que alguien la abre, en Python o en QGIS.
# `CREATE OR REPLACE` permite volver a correr la celda. Le dejamos el `id` del barrio para que QGIS tenga una clave.

# %%
with engine.begin() as con:
    con.execute(text("""
        CREATE OR REPLACE VIEW v_hurtos_barrio AS
        SELECT b.id, b.codigo, b.nombre,
               count(DISTINCT (h.fecha_hecho, h.geometry))                                   AS hechos,
               ST_Area(b.geometry) / 1e6                                                     AS area_km2,
               count(DISTINCT (h.fecha_hecho, h.geometry)) / (ST_Area(b.geometry) / 1e6)     AS hechos_km2,
               b.geometry
        FROM barrios b
        LEFT JOIN hurtos h ON ST_Contains(b.geometry, ST_Transform(h.geometry, 9377))
        WHERE b.subtipo_barriovereda = 1
        GROUP BY b.id, b.codigo, b.nombre, b.geometry"""))
pd.read_sql("SELECT f_table_name, type, srid FROM geometry_columns WHERE f_table_name = 'v_hurtos_barrio'", engine)
# Out:
#       f_table_name          type  srid
# 0  v_hurtos_barrio  MULTIPOLYGON  9377

# %% [markdown]
# ### Líneas en proyección polar
#
# La costa antártica son 2 149 líneas en EPSG:3031, una estereográfica polar con origen en el polo sur. `ST_Length` da metros porque el sistema es métrico;
# `ST_Transform(…, 4326)` devuelve latitud–longitud, y ahí se ve por qué los datos polares no se guardan en 4326: cerca del polo la longitud cambia de −180 a 180 en pocos metros.

# %%
pd.read_sql("""
    SELECT surface AS tipo_de_costa, count(*) AS tramos,
           ROUND((sum(ST_Length(geometry)) / 1e3)::numeric) AS km
    FROM costa_antartida GROUP BY surface ORDER BY km DESC""", engine)
# Out:
#             tipo_de_costa  tramos       km
# 0          grounding line     764  47189.0
# 1     ice shelf and front     355  17931.0
# 2           ice coastline     733  14176.0
# 3          rock coastline     226   2259.0
# 4             ice rumples      55   1435.0
# 5  rock against ice shelf      16    165.0

# %%
pd.read_sql("""
    SELECT id, surface,
           ST_AsText(ST_StartPoint(geometry), 0)                       AS inicio_3031_m,
           ST_AsText(ST_Transform(ST_StartPoint(geometry), 4326), 3)   AS inicio_4326_grados,
           ROUND(ST_Distance(ST_StartPoint(geometry), ST_SetSRID(ST_MakePoint(0, 0), 3031))::numeric / 1e3) AS km_al_polo
    FROM costa_antartida
    ORDER BY km_al_polo LIMIT 5""", engine)
# Out:
#     id         surface           inicio_3031_m       inicio_4326_grados  \
# 0  255  grounding line  POINT(-229038 -709903)  POINT(-162.119 -83.143)
# 1  510  grounding line   POINT(261653 -769931)    POINT(161.23 -82.526)
# 2  509  grounding line   POINT(254178 -773682)   POINT(161.813 -82.515)
# 3  508  grounding line   POINT(273588 -777394)   POINT(160.612 -82.426)
# 4  506  grounding line   POINT(222201 -799472)   POINT(164.468 -82.374)
#
#    km_al_polo
# 0       746.0
# 1       813.0
# 2       814.0
# 3       824.0
# 4       830.0

# %% [markdown]
# Y el mismo continente visto desde dos tablas distintas: el polígono de la Antártida en `paises` (4326, 1:110 m) transformado al 3031 de la costa detallada.
# La base de datos hace la conversión y compara. El perímetro del polígono a escala 1:110 m es una fracción de los kilómetros de la costa detallada:
# cambia la escala y cambia qué se llama «costa» (aquí cuentan también la línea de anclaje y el frente de las plataformas de hielo).

# %%
pd.read_sql("""
    SELECT ROUND((ST_Area(ST_Transform(p.geometry, 3031)) / 1e6)::numeric)              AS area_km2_natural_earth,
           ROUND((ST_Perimeter(ST_Transform(p.geometry, 3031)) / 1e3)::numeric)          AS perimetro_km_natural_earth,
           (SELECT ROUND((sum(ST_Length(geometry)) / 1e3)::numeric) FROM costa_antartida) AS km_costa_add_1km
    FROM paises p WHERE "NAME" = 'Antarctica'""", engine)
# Out:
#    area_km2_natural_earth  perimetro_km_natural_earth  km_costa_add_1km
# 0              12058166.0                     29705.0           83155.0

# %% [markdown]
# ## 6. Del servidor al mapa
#
# `gpd.read_postgis` trae una consulta como `GeoDataFrame`, con el `crs` que dice la base de datos. La consulta puede ser una tabla, una vista o cualquier `SELECT` con geometría.

# %%
vb   = gpd.read_postgis("SELECT * FROM v_hurtos_barrio", engine, geom_col="geometry")
cam  = gpd.read_postgis("SELECT * FROM camaras", engine, geom_col="geometry")
cru  = gpd.read_postgis("SELECT * FROM cruces", engine, geom_col="geometry")
print(vb.crs.to_epsg(), cam.crs.to_epsg(), cru.crs.to_epsg())

fig, ax = plt.subplots(1, 2, figsize=(14, 7))
vb.plot("hechos_km2", scheme="quantiles", k=5, cmap="YlOrRd", legend=True, edgecolor="white", linewidth=.3, ax=ax[0],
        legend_kwds=dict(loc="lower left", fontsize=8, title="hechos / km²"))
ax[0].set_title("Vista v_hurtos_barrio (EPSG:9377)")
vb.plot(color="#eeeeee", edgecolor="white", linewidth=.3, ax=ax[1])
cru.plot(ax=ax[1], markersize=4, color="#1F3864", label="cruces semafóricos (9377)")
cam.to_crs(9377).plot(ax=ax[1], markersize=40, color="#C00000", marker="^", label="cámaras (6257 → 9377)")
ax[1].legend(loc="lower left", fontsize=8); ax[1].set_title("Dos tablas, dos SRID, un mapa")
for a in ax: a.set_axis_off()
plt.tight_layout()
# Out:
# 9377 6257 9377

# %% [markdown]
# Un `SELECT` con condición evita traer lo que no se necesita: aquí solo los hurtos de 2019 dentro de un barrio, ya transformados por el servidor a metros.

# %%
sql = """
    SELECT h.id, h.fecha_hecho, h.modalidad, ST_Transform(h.geometry, 9377) AS geometry
    FROM hurtos h JOIN barrios b ON ST_Contains(b.geometry, ST_Transform(h.geometry, 9377))
    WHERE b.nombre = 'Laureles' AND h.fecha_hecho >= '2019-01-01' AND h.fecha_hecho < '2020-01-01'"""
lau = gpd.read_postgis(sql, engine, geom_col="geometry")
bl  = gpd.read_postgis("SELECT * FROM barrios WHERE nombre = 'Laureles'", engine, geom_col="geometry")
ax = bl.plot(color="#eeeeee", edgecolor="#1F3864", figsize=(6, 6))
lau.plot(ax=ax, markersize=10, color="#C00000", alpha=.6)
hechos = lau.drop_duplicates(subset=["fecha_hecho", "geometry"]).shape[0]
ax.set_title(f"Laureles, hurtos a residencia 2019: {len(lau)} bienes, {hechos} hechos", fontsize=10)
ax.set_axis_off()

# %%
pa  = gpd.read_postgis("SELECT * FROM paises", engine, geom_col="geometry")
co  = gpd.read_postgis("SELECT * FROM costa_antartida", engine, geom_col="geometry")
ant = gpd.read_postgis("SELECT ST_Transform(geometry, 3031) AS geometry FROM paises WHERE \"NAME\" = 'Antarctica'", engine, geom_col="geometry")

fig, ax = plt.subplots(1, 2, figsize=(14, 6.5))
pa.plot("GDP_MD", cmap="viridis", legend=True, ax=ax[0], legend_kwds=dict(shrink=.5, label="PIB (millones USD)"))
ax[0].set_title("paises (EPSG:4326, grados)")
ant.plot(color="#dddddd", ax=ax[1])
co.plot("surface", categorical=True, legend=True, linewidth=.6, ax=ax[1], legend_kwds=dict(loc="lower left", fontsize=7))
ax[1].set_title("costa_antartida (EPSG:3031, metros desde el polo)"); ax[1].set_axis_off()
plt.tight_layout()

# %% [markdown]
# En la proyección polar la Antártida se ve como en el globo: un continente centrado, no una franja estirada en el borde inferior del mapa mundial.
# La misma tabla `paises` da la franja (izquierda) y, transformada por el servidor, el fondo gris del panel derecho.

# %% [markdown]
# ## 7. La misma base de datos desde QGIS
#
# Nada de lo anterior es de Python. QGIS habla el mismo SQL con el mismo servidor:
#
# 1. **Capa → Añadir capa → Añadir capas PostGIS…** (o el icono del elefante en el panel *Explorador*, clic derecho en *PostgreSQL → Nueva conexión*).
# 2. Nueva conexión: *Nombre* `curso`, *Servidor* `localhost`, *Puerto* `5440`, *Base de datos* `curso`, *Autenticación básica* usuario `postgres`, contraseña `1111`. **Probar conexión** y *Aceptar*.
# 3. *Conectar*: en el esquema `public` aparecen las seis tablas y la vista `v_hurtos_barrio` (el esquema `tiger`, con tablas vacías del censo de EE. UU., viene con la imagen: ignórelo); cada una muestra su tipo de geometría y su SRID, leídos de `geometry_columns`. Las tablas traen su clave (`id`); para la vista QGIS pregunta cuál columna usar como identificador: elija `id`.
# 4. Seleccionar `barrios`, `camaras`, `costa_antartida` y `v_hurtos_barrio` → *Añadir*. QGIS reproyecta al vuelo al SRC del proyecto: barrios (9377) y cámaras (6257) caen en su sitio sin exportar nada.
# 5. Para la costa, cambie el SRC del proyecto a EPSG:3031 (botón inferior derecho) y verá el polo centrado.
#
# Lo que cambia respecto a los archivos:
#
# * **Un solo origen**: si alguien corrige un barrio en QGIS (la tabla tiene clave primaria, así que es editable), la siguiente corrida de este notebook ya lo ve. No hay copias desincronizadas.
# * **Filtros en el servidor**: en *Propiedades de la capa → Origen → Filtro* se escribe el `WHERE` (`fecha_hecho >= '2019-01-01'`) y QGIS solo pide esas filas.
# * **Varias personas a la vez**: el servidor ordena las escrituras; dos usuarios no se pisan el archivo.
# * **Consultas guardadas**: la vista `v_hurtos_barrio` aparece en QGIS como una capa más, siempre con el conteo al día.
#
# Otras herramientas que abren la misma base de datos con los mismos cinco datos de conexión: pgAdmin, DBeaver, R (`sf::st_read` con `RPostgres`), o `psql` dentro del contenedor.

# %% [markdown]
# ## 8. Cerrar
#
# El contenedor sigue corriendo hasta que se apague (`docker stop curso-postgis`); los datos quedan en el volumen `curso_pgdata` y estarán ahí la próxima vez que haga `docker start curso-postgis`.
# Desde Python basta liberar las conexiones.

# %%
pd.read_sql("""
    SELECT relname AS tabla, n_live_tup AS filas, pg_size_pretty(pg_total_relation_size(relid)) AS tamano
    FROM pg_stat_user_tables WHERE schemaname = 'public' ORDER BY n_live_tup DESC""", engine)
# Out:
#              tabla  filas   tamano
# 0           hurtos  38343    10 MB
# 1  spatial_ref_sys   8502  7152 kB
# 2  costa_antartida   2149   840 kB
# 3           cruces    724   224 kB
# 4          barrios    332  5200 kB
# 5           paises    177   272 kB
# 6          camaras     22    48 kB

# %%
engine.dispose()

# %% [markdown]
# ### Fuentes
#
# * Barrios y veredas, cruces semafóricos, cámaras de fotodetección: Alcaldía de Medellín, GeoMedellín / SIMM (datos abiertos, 2025).
# * Hurto a residencia: MEData, Sistema de Información para la Seguridad y la Convivencia (SISC), 2003–2022.
# * Países: Natural Earth, *Admin 0 – Countries*, 1:110 m, v5.
# * Costa antártica: SCAR Antarctic Digital Database, *High resolution coastline* v7.10 (British Antarctic Survey); simplificada aquí a 1 km y sin tramos menores de 5 km.
# * PostGIS 3 Reference: https://postgis.net/docs/ · Obe, R. & Hsu, L. (2021). *PostGIS in Action*, 3.ª ed., Manning.
