# %%
import pandas as pd

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_csv('./data/hurto_a_residencia.csv')

# %%
df.head()
# Out:
#                      fecha_hecho  cantidad   latitud   longitud    sexo  edad  \
# 0  2017-01-01T13:51:00.000-05:00       1.0  6.251238 -75.586712   Mujer    38
# 1  2017-01-01T13:51:00.000-05:00       1.0  6.251238 -75.586712   Mujer    38
# 2  2017-01-01T13:51:00.000-05:00       1.0  6.251238 -75.586712   Mujer    38
# 3  2017-01-01T00:00:00.000-05:00       1.0  6.262758 -75.593850  Hombre    62
# 4  2017-01-01T00:00:00.000-05:00       1.0  6.280006 -75.564721   Mujer    53
#
#   estado_civil grupo_actor actividad_delictiva parentesco  ...  \
# 0    Casado(a)    Sin dato            Sin dato   Sin dato  ...
# 1    Casado(a)    Sin dato            Sin dato   Sin dato  ...
# 2    Casado(a)    Sin dato            Sin dato   Sin dato  ...
# 3   Soltero(a)    Sin dato            Sin dato   Sin dato  ...
# 4   Soltero(a)    Sin dato            Sin dato   Sin dato  ...
#
#                    lugar sede_receptora  \
# 0  Hotel, motel y hostal       Laureles
# 1  Hotel, motel y hostal       Laureles
# 2  Hotel, motel y hostal       Laureles
# 3  Hotel, motel y hostal       Laureles
# 4  Hotel, motel y hostal       Aranjuez
#
#                                           bien  \
# 0                 Accesorios prendas de vestir
# 1  Electrodoméstico video y audio y accesorios
# 2                                      Celular
# 3                                    Bicicleta
# 4                                         Peso
#
#                                     categoria_bien grupo_bien modelo  \
# 0                   Prendas de vestir y accesorios  Mercancía     -1
# 1                                Electrodomésticos  Mercancía     -1
# 2                                       Tecnología  Mercancía     -1
# 3                        Vehículos de 2 o 4 ruedas   Vehículo     -1
# 4  Dinero, joyas, piedras preciosas y título valor  Mercancía     -1
#
#       color   permiso unidad_medida                fecha_ingestion
# 0       Oro  Sin dato      Sin dato  2025-03-06T04:05:02.000-05:00
# 1     Negro  Sin dato      Sin dato  2025-03-06T04:05:02.000-05:00
# 2     Negro  Sin dato      Sin dato  2025-03-06T04:05:02.000-05:00
# 3  Sin dato  Sin dato      Sin dato  2025-03-06T04:05:02.000-05:00
# 4  Sin dato  Sin dato      Sin dato  2025-03-06T04:05:02.000-05:00
#
# [5 rows x 36 columns]

# %%
df.keys()
# Out:
# Index(['fecha_hecho', 'cantidad', 'latitud', 'longitud', 'sexo', 'edad',
#        'estado_civil', 'grupo_actor', 'actividad_delictiva', 'parentesco',
#        'ocupacion', 'discapacidad', 'grupo_especial', 'medio_transporte',
#        'nivel_academico', 'testigo', 'conducta', 'modalidad',
#        'caracterizacion', 'conducta_especial', 'arma_medio', 'articulo_penal',
#        'categoria_penal', 'nombre_barrio', 'codigo_barrio', 'codigo_comuna',
#        'lugar', 'sede_receptora', 'bien', 'categoria_bien', 'grupo_bien',
#        'modelo', 'color', 'permiso', 'unidad_medida', 'fecha_ingestion'],
#       dtype='object')

# %% [markdown]
# ## Exploración de los datos

# %%
df['nombre_barrio'].unique()
# Out:
# array(['Naranjal', 'Los Colores', 'Bermejal-Los Alamos', 'Los Ángeles',
#        'La Florida', 'Media Luna', 'Belén', 'Córdoba', 'Aures No.2',
#        'La Loma de los Bernal', 'Los Balsos No.1', 'Santa Fé', 'Castilla',
#        'Bolivariana', 'La Piñuela', 'El Tesoro', 'Berlin', 'Las Granjas',
#        'Pedregal', 'Rosales', 'Las Acacias', 'Las Lomas No.1',
#        'El Danubio', 'San Germán', 'El Rincón', 'Los Conquistadores',
#        'Tejelo', 'Los Alpes', 'La Palma', 'San Miguel',
#        'Nueva Villa del Aburrá', 'Villa Lilliam', 'Miraflores',
#        'Área Urbana Cgto. San Antonio de Prado', 'Carpinelo', 'La Rosa',
#        'El Nogal-Los Almendros', 'Cristo Rey', 'Loreto', 'Alejandría',
#        'Altos del Poblado', 'La Pradera', 'Laureles', 'La Gloria',
#        'Francisco Antonio Zea', 'El Poblado', 'La Salle',
#        'Juan XXIIIi la Quiebra', 'Barrio Caycedo', 'Versalles No.2',
#        'Boston', 'Jesús Nazareno', 'Llanaditas', 'Alfonso López',
#        'Playón de los Comuneros', 'La Esperanza No.2', 'Lorena',
#        'Los Cerros el Vergel', 'La Mansión',
#        'Área Urbana Cgto. San Cristóbal', 'Florencia', 'Sucre', 'Estadio',
#        'Barrio Colón', 'San Javier No.1', 'Aranjuez', 'San Joaquín',
#        'Nuevos Conquistadores', 'Cuarta Brigada', 'Altamira',
#        'Bomboná No.1', 'La Alpujarra', 'Villa Nueva',
#        'Manrique Central No.1', 'Robledo', 'La Candelaria',
#        'La Aguacatala', 'Simón Bolívar', 'Barrio Cristóbal', 'La América',
#        'Campo Amor', 'Alejandro Echavarría', 'Prado', 'Lalinde',
#        'Cucaracho', 'San Bernardo', 'Las Palmas', 'Calasanz', 'Castropol',
#        'San Lucas', 'Fátima', 'Santa Cruz', 'Santa María de los Ángeles',
#        'Carlos E. Restrepo', 'Guayaquil', 'Los Alcázares',
#        'La Castellana', 'La Pilarica', 'Caribe', 'Las Mercedes',
#        'Bosques de San Pablo', 'La Colina', 'San Jose del Manzanillo',
#        'Granada', 'La Floresta', 'Campo Valdés No.1', 'Girardot',
#        'Manrique Central No.2', 'Las Playas', 'Los Mangos', 'La Mota',
#        'Santa Lucía', 'San Benito', 'Los Balsos No.2', 'El Velódromo',
#        'Suramericana', 'Estación Villa', 'Tricentenario', 'Sin dato',
#        'Trinidad', 'Toscana', 'El Salvador', 'Las Lomas No.2', 'Palenque',
#        'Villa Carlota', 'Santa Teresita', 'Calasania Parte Alta',
#        'Patio Bonito', 'San Martín de Porres', 'Eduardo Santos',
#        'La Esperanza', 'Santa Mónica', 'Los Naranjos', 'Manila',
#        'Campo Valdés No.2', 'Los Pinos', 'Florida Nueva',
#        'Parque Juan Pablo II', 'Villa Hermosa', 'Guayabal',
#        'Santo Domingo Savio No.1', 'Sevilla', 'Santander',
#        'El Diamante No.2', 'Las Palmas S.E.', 'Belencito', 'Fuente Clara',
#        'Las Violetas', 'Moscú No.2', 'Miranda', 'Ferrini',
#        'Héctor Abad Gómez', 'Kennedy', 'Moravia', 'Oriente', 'El Salado',
#        'Manrique Oriental', 'Asomadera No.1', 'La Isla', 'Astorga',
#        'San Pedro', 'Brasilia', 'Trece de Noviembre', 'Las Playas S.C.',
#        'Bomboná No.2', 'El Castillo', 'Aures No.1', 'Diego Echavarría',
#        'Campo Alegre', 'El Raizal', 'Metropolitano', 'Moscú No.1',
#        'Cataluña', 'El Pomar', 'B. Cerro el Volador', 'Miravalle',
#        'San Antonio', 'Altavista Sector Central', 'Monteclaro',
#        'San Pablo', 'Área de expansión San Antonio De Prado',
#        'Barrios de Jesús', 'El Chagualo', 'Boyacá', 'Gerona',
#        'La Francia', 'Progreso', 'Las Independencias', 'San Isidro',
#        'Las Brisas', 'Andalucía', 'Buenos Aires',
#        'Piedras Blancas Matasano', 'Área de expansión Pajarito',
#        'Betania', 'La Cruz', 'El Diamante', 'El Yolombo', 'Pajarito',
#        'Villa Guadalupe', 'Palmitas sector central', 'El Corazón',
#        'Las Estancias', 'Travesias', 'Bello Horizonte', 'Santa Margarita',
#        'San Diego', 'Villatina', 'La Loma', 'La Palma S.C.', 'El Triunfo',
#        'Área de expansión Calasanz', 'El Pesebre', 'Versalles No.1',
#        'La Libertad', 'Antonio Nariño', 'Villa Niza', 'Granizal',
#        'Corazón de Jesús', 'La Avanzada', 'El Llano', 'El Pinal',
#        'Popular', 'La Sucia', 'Doce de Octubre No.1', 'Aguas Frias',
#        'Santa Inés', 'Altavista', 'Ecoparque Cerro El Volador',
#        'Plaza de Ferias', 'Facultad de Minas U. Nal', 'Perpetuo Socorro',
#        'La Hondonada', 'Veinte de Julio', 'Calle Nueva', 'Enciso',
#        'Fac. Veterinaria y Zootecnia U.De.A.', 'La Milagrosa',
#        'Doce de Octubre No.2', 'El Compromiso', 'Belalcázar', 'Picacho',
#        'Asomadera No.2', 'Santa Elena sector central',
#        'San José la Cima No.2', 'Ocho de Marzo', 'San Javier No.2',
#        'El Placer', 'Villa Turbay', 'Área de expansión Belén',
#        'Piedra Gorda', 'Santa Rosa de Lima', 'San José la Cima No.1',
#        'López de Mesa', 'Cerro Nutibara', 'San Pablo A.V.', 'Yarumalito',
#        'Santo Domingo Savio No.2', 'Blanquizal', 'Picachito',
#        'Centro Administrativo', 'Parque Norte', 'Olaya Herrera',
#        'María Cano-Carambolas', 'Nueva Villa de la Iguaná', 'El Socorro',
#        'Batallón Cuarta Brigada', 'Potrerito', 'La Verde', 'Mazo',
#        'Las Esmeraldas', 'U.D. Atanasio Girardot',
#        'Sin dato 90 Santa Elena', 'La Ladera', 'Tenche', 'Villa Flora',
#        'La Frontera', 'El Rodeo', 'El Picacho', 'Villa del Socorro',
#        'Montanita', 'El Uvito', 'Pablo VI', 'Barro Blanco', 'Palermo',
#        'Barrio Colombia', 'El Corazon el Morro', 'Batallón Girardot',
#        'Pajarito S.C.', 'El Carmelo', 'El Cerro', 'La Ilusion', 'El Plan',
#        'Área de expansión Altavista', 'Cementerio Universal',
#        'Mirador del Doce', 'Terminal de Transporte', 'Pedregal Alto',
#        'V. El Salado', 'Juan Pablo II', 'La Sierra', 'Progreso No.2',
#        'Facultad de Minas U. Nacional', 'Aldea Pablo VI',
#        'La Florida S.A.P.', 'El Astillero', 'Universidad Nacional',
#        'La Aldea', 'La Cuchilla', 'Oleoducto', 'El Jardin',
#        'Naranjal S.C.', 'Jardín Botánico', 'Volcana Guayabal',
#        'La Esperanza A.V.', 'San Jose de La Montaña',
#        'Sin dato 60 San Cristobal', 'Cerro Nutibara Ins.',
#        'El Llano Santa Elena', 'Boqueron', 'Buga Patio Bonito',
#        'Universidad de Antioquia', 'U.P.B', 'San Jose', 'Asomadera No.3',
#        'Hospital San Vicente de Paúl', 'La Frisola',
#        'Sin dato 50 Palmitas', 'Sin dato 9 Buenos Aires',
#        'Sin dato 80 San Antonio de Prado', 'Sin dato 13 San Javier',
#        'Sin dato 16 Belen', 'Sin dato 6 Doce de Octubre'], dtype=object)

# %% [markdown]
# ## Creación base de datos

# %%
from sqlalchemy import create_engine, text

# Cambia los parámetros según tu entorno
user = "postgres"
password = "1111"
host = "localhost"
port = "5440"
database = "postgres" # Base de datos por defecto

# Crear conexión
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}")

# Comprobación básica
with engine.connect() as conn:
    print("✅ Conectado a PostgreSQL/PostGIS:", conn)
# Out:
# ✅ Conectado a PostgreSQL/PostGIS: <sqlalchemy.engine.base.Connection object at 0x10a94fe00>

# %%
create_tables_sql = """
-- Asegurar extensión PostGIS
CREATE EXTENSION IF NOT EXISTS postgis;

-- Tabla de comunas
CREATE TABLE IF NOT EXISTS comuna (
    id_comuna SMALLINT PRIMARY KEY,
    nombre_comuna VARCHAR(100) NOT NULL
);

-- Tabla de barrios
CREATE TABLE IF NOT EXISTS barrio (
    id_barrio SERIAL PRIMARY KEY,
    nombre_barrio VARCHAR(100) UNIQUE NOT NULL,
    codigo_barrio VARCHAR(50) UNIQUE NOT NULL,
    codigo_comuna SMALLINT NOT NULL REFERENCES comuna(id_comuna)
);

-- Tabla de modalidades de hurto
CREATE TABLE IF NOT EXISTS modalidad (
    id_modalidad SERIAL PRIMARY KEY,
    descripcion VARCHAR(100) UNIQUE NOT NULL
);

-- Tabla de lugares donde ocurre el hurto
CREATE TABLE IF NOT EXISTS lugar (
    id_lugar SERIAL PRIMARY KEY,
    descripcion VARCHAR(100) UNIQUE NOT NULL
);

-- Tabla de grupos de bienes
CREATE TABLE IF NOT EXISTS grupo_bien (
    id_grupo SERIAL PRIMARY KEY,
    descripcion VARCHAR(100) UNIQUE NOT NULL
);

-- Tabla de categorías de bienes
CREATE TABLE IF NOT EXISTS categoria_bien (
    id_categoria SERIAL PRIMARY KEY,
    descripcion VARCHAR(100) UNIQUE NOT NULL,
    id_grupo INT REFERENCES grupo_bien(id_grupo)
);

-- Tabla de bienes específicos
CREATE TABLE IF NOT EXISTS bien (
    id_bien SERIAL PRIMARY KEY,
    descripcion VARCHAR(150) UNIQUE NOT NULL,
    id_categoria INT REFERENCES categoria_bien(id_categoria)
);
"""

# %%
hechos_sql = """
-- Tabla principal: hechos delictivos
CREATE TABLE IF NOT EXISTS hecho_delictivo (
    id_hecho SERIAL PRIMARY KEY,
    fecha_hecho TIMESTAMP NOT NULL,
    cantidad SMALLINT,
    ubicacion geometry(Point, 4326),
    id_barrio INT REFERENCES barrio(id_barrio),
    id_modalidad INT REFERENCES modalidad(id_modalidad),
    id_lugar INT REFERENCES lugar(id_lugar),
    id_bien INT REFERENCES bien(id_bien),
    fecha_ingestion TIMESTAMP
);

-- Índice espacial para acelerar consultas geográficas
CREATE INDEX IF NOT EXISTS idx_hecho_geom
ON hecho_delictivo
USING GIST (ubicacion);
"""

# %%
# Ejecutar los scripts
with engine.connect() as conn:
    conn.execute(text(create_tables_sql))
    conn.execute(text(hechos_sql))
    conn.commit()

print("✅ Tablas creadas correctamente en la base de datos.")
# Out:
# ✅ Tablas creadas correctamente en la base de datos.

# %% [markdown]
# ## Cargar datos

# %%
def insert_unique_values(conn, table, column, values):
    """Inserta valores únicos evitando duplicados."""
    for v in sorted(set(values)):
        if pd.notna(v):
            conn.execute(text(f"""
                INSERT INTO {table} ({column})
                VALUES (:val)
                ON CONFLICT ({column}) DO NOTHING;
            """), {"val": str(v).strip()})

# %%
with engine.begin() as conn:
    # ===============================================================
    # --- COMUNA ---
    # ===============================================================
    conn.execute(text("DELETE FROM comuna;"))
    comunas = (
        df["codigo_comuna"]
        .dropna()
        .astype(str)
        .str.strip()
        .unique()
    )

    for c in sorted(comunas):
        # Inserta solo si es número, maneja 'Sin dato'
        if c.replace(".", "").isdigit():
            conn.execute(
                text("""
                    INSERT INTO comuna (id_comuna, nombre_comuna)
                    VALUES (:id, :nombre)
                    ON CONFLICT DO NOTHING;
                """),
                {"id": int(float(c)), "nombre": f"Comuna {c}"},
            )
        else:
            conn.execute(
                text("""
                    INSERT INTO comuna (id_comuna, nombre_comuna)
                    VALUES (0, 'Sin dato')
                    ON CONFLICT DO NOTHING;
                """)
            )

    # ===============================================================
    # --- BARRIO ---
    # ===============================================================
    conn.execute(text("DELETE FROM barrio;"))
    barrios = (
        df[["nombre_barrio", "codigo_barrio", "codigo_comuna"]]
        .dropna(subset=["nombre_barrio"])
        .drop_duplicates()
    )

    for _, row in barrios.iterrows():
        codigo_comuna = str(row["codigo_comuna"]).strip()
        id_comuna = 0
        if isinstance(codigo_comuna, str) and codigo_comuna.replace(".", "").isdigit():
            id_comuna = int(float(codigo_comuna))

        conn.execute(
            text("""
                INSERT INTO barrio (nombre_barrio, codigo_barrio, codigo_comuna)
                VALUES (:nombre, :codigo, :comuna)
                ON CONFLICT (nombre_barrio) DO NOTHING;
            """),
            {
                "nombre": str(row["nombre_barrio"]).strip(),
                "codigo": str(row["codigo_barrio"]).replace("#", "").strip(),
                "comuna": id_comuna,
            },
        )

    # ===============================================================
    # --- MODALIDAD ---
    # ===============================================================
    modalidades = (
        df["modalidad"]
        .dropna()
        .astype(str)
        .str.strip()
        .replace("", "Sin dato")
        .unique()
    )

    conn.execute(text("DELETE FROM modalidad;"))
    for m in sorted(set(modalidades)):
        conn.execute(
            text("""
                INSERT INTO modalidad (descripcion)
                VALUES (:desc)
                ON CONFLICT (descripcion) DO NOTHING;
            """),
            {"desc": m},
        )

    # ===============================================================
    # --- LUGAR ---
    # ===============================================================
    lugares = (
        df["lugar"]
        .dropna()
        .astype(str)
        .str.strip()
        .replace("", "Sin dato")
        .unique()
    )

    conn.execute(text("DELETE FROM lugar;"))
    for l in sorted(set(lugares)):
        conn.execute(
            text("""
                INSERT INTO lugar (descripcion)
                VALUES (:desc)
                ON CONFLICT (descripcion) DO NOTHING;
            """),
            {"desc": l},
        )

    # ===============================================================
    # --- GRUPO_BIEN ---
    # ===============================================================
    grupos = (
        df["grupo_bien"]
        .dropna()
        .astype(str)
        .str.strip()
        .replace("", "Sin dato")
        .unique()
    )

    conn.execute(text("DELETE FROM grupo_bien;"))
    for g in sorted(set(grupos)):
        conn.execute(
            text("""
                INSERT INTO grupo_bien (descripcion)
                VALUES (:desc)
                ON CONFLICT (descripcion) DO NOTHING;
            """),
            {"desc": g},
        )

    # ===============================================================
    # --- CATEGORIA_BIEN ---
    # ===============================================================
    conn.execute(text("DELETE FROM categoria_bien;"))
    categorias = (
        df[["categoria_bien", "grupo_bien"]]
        .dropna(subset=["categoria_bien"])
        .drop_duplicates()
    )

    for _, row in categorias.iterrows():
        categoria = str(row["categoria_bien"]).strip()
        grupo = str(row["grupo_bien"]).strip()

        conn.execute(
            text("""
                INSERT INTO categoria_bien (descripcion, id_grupo)
                VALUES (
                    :desc,
                    (SELECT id_grupo FROM grupo_bien WHERE descripcion = :grupo LIMIT 1)
                )
                ON CONFLICT (descripcion) DO NOTHING;
            """),
            {"desc": categoria, "grupo": grupo},
        )

    # ===============================================================
    # --- BIEN ---
    # ===============================================================
    conn.execute(text("DELETE FROM bien;"))
    bienes = (
        df[["bien", "categoria_bien"]]
        .dropna(subset=["bien"])
        .drop_duplicates()
    )

    for _, row in bienes.iterrows():
        bien = str(row["bien"]).strip()
        cat = str(row["categoria_bien"]).strip()

        conn.execute(
            text("""
                INSERT INTO bien (descripcion, id_categoria)
                VALUES (
                    :desc,
                    (SELECT id_categoria FROM categoria_bien WHERE descripcion = :cat LIMIT 1)
                )
                ON CONFLICT (descripcion) DO NOTHING;
            """),
            {"desc": bien, "cat": cat},
        )

# %%
from tqdm import tqdm

with engine.begin() as conn:
    conn.execute(text("DELETE FROM hecho_delictivo;"))
    for _, row in tqdm(df.iterrows(), total=len(df)):
        try:
            conn.execute(text("""
                INSERT INTO hecho_delictivo (
                    fecha_hecho, cantidad, ubicacion,
                    id_barrio, id_modalidad, id_lugar, id_bien, fecha_ingestion
                ) VALUES (
                    :fecha, :cant,
                    ST_SetSRID(ST_MakePoint(:lon, :lat), 4326),
                    (SELECT id_barrio FROM barrio WHERE nombre_barrio = :barrio LIMIT 1),
                    (SELECT id_modalidad FROM modalidad WHERE descripcion = :mod LIMIT 1),
                    (SELECT id_lugar FROM lugar WHERE descripcion = :lug LIMIT 1),
                    (SELECT id_bien FROM bien WHERE descripcion = :bien LIMIT 1),
                    :ing
                );
            """), {
                "fecha": row["fecha_hecho"],
                "cant": row["cantidad"] if pd.notna(row["cantidad"]) else 1,
                "lon": row["longitud"],
                "lat": row["latitud"],
                "barrio": str(row["nombre_barrio"]).strip(),
                "mod": str(row["modalidad"]).strip(),
                "lug": str(row["lugar"]).strip(),
                "bien": str(row["bien"]).strip(),
                "ing": row["fecha_ingestion"]
            })
        except Exception:
            pass  # omite registros con referencias faltantes
# Out:
# 100%|██████████| 42673/42673 [00:17<00:00, 2476.99it/s]

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT COUNT(*) FROM hecho_delictivo;"))
    print("✅ Registros cargados en hecho_delictivo:", result.scalar())

    for table in ["comuna", "barrio", "modalidad", "lugar", "grupo_bien", "categoria_bien", "bien"]:
        count = conn.execute(text(f"SELECT COUNT(*) FROM {table};")).scalar()
        print(f"📘 {table}: {count} filas")
# Out:
# ✅ Registros cargados en hecho_delictivo: 42673
# 📘 comuna: 22 filas
# 📘 barrio: 333 filas
# 📘 modalidad: 26 filas
# 📘 lugar: 49 filas
# 📘 grupo_bien: 5 filas
# 📘 categoria_bien: 47 filas
# 📘 bien: 353 filas
